# %% [markdown]
# # <center>PA1<center>

# %% [markdown]
# <p>Team Name: Martin-Mire-Crawford
# <p>Student Names: Kyle Martin, Allen Mire, Garret Crawford
# <p>Student W#s: W0470161, W0445696, W0682298

# %% [markdown]
# ## Instructions
# Use generic coding style unless hard-coded values are really necessary.<br>
# Your code must be efficient and use self-explanatory naming.<br>
# Use appropriate Python library methods for each task instead of using loops.<br>
# Run your entire code and save. Then submit this <b>saved</b> copy.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize'] = [12, 12]
plt.rcParams['figure.subplot.wspace'] = .5

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('./INPUT/Dataset.csv')

# %%
numeric_labels = ['type' ,'amount' ,'oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']
print(df[numeric_labels])
# Out:
#              type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT     9839.64      170136.00       160296.36            0.00
# 1         PAYMENT     1864.28       21249.00        19384.72            0.00
# 2        TRANSFER      181.00         181.00            0.00            0.00
# 3        CASH_OUT      181.00         181.00            0.00        21182.00
# 4         PAYMENT    11668.14       41554.00        29885.86            0.00
# ...           ...         ...            ...             ...             ...
# 6362615  CASH_OUT   339682.13      339682.13            0.00            0.00
# 6362616  TRANSFER  6311409.28     6311409.28            0.00            0.00
# 6362617  CASH_OUT  6311409.28     6311409.28            0.00        68488.84
# 6362618  TRANSFER   850002.52      850002.52            0.00            0.00
# 6362619  CASH_OUT   850002.52      850002.52            0.00      6510099.11
#
#          newbalanceDest
# ...

# %% [markdown]
# ## Visual Exploration of Data

# %% [markdown]
# ### Histograms

# %%
for i in range(0, 6):
    plt.figure()
    plt.hist(df[numeric_labels[i]], bins=10, edgecolor='white')
    plt.title(numeric_labels[i])
    plt.show()

# %% [markdown]
# ### Distributions

# %% [markdown]
# ### Box-Whisker Plots

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Quality & Cleaning

# %% [markdown]
# Instruction: Add a comment for each method

# %% [markdown]
# ## Handling Redundancy

# %% [markdown]
# ### X-square Test

# %% [markdown]
# ### Correlation Analysis

# %%
corrcoef = df[numeric_labels].corr()
corrcoef
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
#
#                 newbalanceDest
# amount                0.459304
# oldbalanceOrg         0.042029
# newbalanceOrig        0.041837
# oldbalanceDest        0.976569
# newbalanceDest        1.000000

# %% [markdown]
# ### Visual Exploration (scatter-plot matrix)

# %%
sm = pd.plotting.scatter_matrix(df[numeric_labels])

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# ### PCA

# %% [markdown]
# ## Discretization

# %% [markdown]
# ### Binning

# %% [markdown]
# ### Histogram of Discretized Attribute

# %% [markdown]
# ### X-square Test of Discretized Attributes

# %% [markdown]
# ### Visual Exploration (scatter-plot matrix) of Discretized Attributes

# %% [markdown]
# ## Feature Selection/Generation

# %% [markdown]
# ### Select Features

# %% [markdown]
# ### Generate Features

# %% [markdown]
# # Generate Clusters

# %% [markdown]
# ## K-means

# %% [markdown]
# ## Hierarchical

# %% [markdown]
# # Evaluation of Clusters
# See instructions provided in the report template

# %% [markdown]
# # Comparison of Clustering Outcomes
# See instructions provided in the report template

# %% [markdown]
# ## <center> REFERENCES </center>
# List resources (book, internet page, etc.) that you used to complete this challenge.
